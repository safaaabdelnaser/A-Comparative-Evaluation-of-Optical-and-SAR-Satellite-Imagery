# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.1/910.1 kB 14.1 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from ultralytics import YOLO
from IPython.display import display,Image
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.62 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6095.9/8062.4 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="0CmUpH1ztq89bYqIYjF1")
project = rf.workspace("object-detection-efq50").project("open-fs8xe")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 2.9 MB/s eta 0:00:00
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to open-4 in yolov8:: 100%|██████████| 24754/24754 [00:02<00:00, 10608.04it/s]

# %%
# !ls
# Out:
# open-4

# %%
# %cd /kaggle/working/open-4

# %%
# !ls

# %%
# !yolo task=detect mode=train model=yolov8x.pt data='/kaggle/input/opensar-data/data.yaml' epochs=29 imgsz=800 plots=True val=true save=true batch=8 close_mosaic=0

# %%
# !yolo task=detect mode=val model=/kaggle/working/runs/detect/train/weights/best.pt data='/kaggle/input/opensar-data/data.yaml' iou=.4 save_json=true

# %%
# !yolo task=detect mode=predict model='/kaggle/working/runs/detect/train/weights/best.pt' conf=0.5 source="/kaggle/working/open-4/test/images"

# %%
from ultralytics import YOLO

# Load the model
model = YOLO('/kaggle/input/epoch125-weight/last.pt')  

results = model.train(epochs=27 ,imgsz=800 , plots=True , val=True, save=True ,batch=8 ,close_mosaic=0)  # Replace 10 with the desired number of epochs
# Out:
# Ultralytics 8.3.62 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val model=/kaggle/working/runs/detect/train/weights/best.pt data='/kaggle/input/yamlfile-open/data.yaml' iou=.4 save_json=true
# Out:
# Ultralytics 8.3.62 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 268 layers, 68,132,235 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /kaggle/working/open-4/valid/labels.cache... 1033 images, 0 backgr
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1033       1033      0.867      0.879      0.911      0.637
#           Bulk Carrier        163        163      0.916      0.926      0.954      0.679
#                  Cargo        215        215      0.873       0.86      0.911      0.635
#         Container Ship        282        282       0.84      0.862        0.9      0.633
#                Fishing         63         63      0.816       0.81      0.844      0.522
#          General Cargo         50         50      0.927        0.9      0.932      0.664
#    Oil Products Tanker         36         36      0.857      0.917      0.939       0.69
# ...

# %%
# !yolo task=detect mode=predict model='/kaggle/working/runs/detect/train/weights/best.pt' conf=0.5 source="/kaggle/working/open-4/test/images"
# Out:
# Ultralytics 8.3.62 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 268 layers, 68,132,235 parameters, 0 gradients, 257.4 GFLOPs
#
# image 1/523 /kaggle/working/open-4/test/images/1001_jpg.rf.28caa6809e99eb30aca79c507b221d2e.jpg: 800x800 1 General Cargo, 114.2ms
# image 2/523 /kaggle/working/open-4/test/images/1012_jpg.rf.02cb3c476532da54b9a4f51606ee060b.jpg: 800x800 1 Oil-Chemical Tanker, 96.3ms
# image 3/523 /kaggle/working/open-4/test/images/1012_jpg.rf.620c6841e8cc329b7ce6933f30adbd1e.jpg: 800x800 1 Oil-Chemical Tanker, 102.3ms
# image 4/523 /kaggle/working/open-4/test/images/1016_jpg.rf.fc5bdc4d03877a18083c5a7bc4cba381.jpg: 800x800 1 Bulk Carrier, 104.1ms
# image 5/523 /kaggle/working/open-4/test/images/1028_jpg.rf.a9ab3e4c32e7524fb28f1a6b7e54c926.jpg: 800x800 1 Bulk Carrier, 102.6ms
# image 6/523 /kaggle/working/open-4/test/images/1036_jpg.rf.6f65f4967abfd73fd8852a89d068f14a.jpg: 800x800 1 Cargo, 104.0ms
# ...

# %%
from IPython.display import FileLink

#FileLink('/kaggle/working/open-4.zip')
#FileLink('/kaggle/working/open-4/runs.zip')
# !zip -r zip_folder.zip runs
# Out:
# updating: runs/ (stored 0%)
# updating: runs/detect/ (stored 0%)
# updating: runs/detect/predict/ (stored 0%)
# updating: runs/detect/predict/2606_jpg.rf.e29baa2d1a0dbe237e4277af0b820aed.jpg (deflated 26%)
# updating: runs/detect/predict/1341_jpg.rf.40500fd3035b3d909516e5e410840813.jpg (deflated 8%)
# updating: runs/detect/predict/2521_jpg.rf.fba628c770561b6292fcc7207802d760.jpg (deflated 14%)
# updating: runs/detect/predict/147_jpg.rf.ce6e189d16d828e175009f446294d3d2.jpg (deflated 8%)
# updating: runs/detect/predict/2952_jpg.rf.acdc65fd81413a5f80c0b00cfd24d7b3.jpg (deflated 18%)
# updating: runs/detect/predict/854_jpg.rf.a5ebe41a0fed328d39140dc93b165e7b.jpg (deflated 29%)
# updating: runs/detect/predict/624_jpg.rf.fc6811e1b467e98df820855fc1d6e637.jpg (deflated 19%)
# updating: runs/detect/predict/2637_jpg.rf.06283c98a640a68a16dba6e80f27ea60.jpg (deflated 9%)
# updating: runs/detect/predict/281_jpg.rf.cc7924877c7dead9b7e410f9f319a247.jpg (deflated 20%)
# ...

# %%
from IPython.display import FileLink

def download_file(file_path):
    return FileLink(file_path)

download_file('/kaggle/working/zip_folder.zip')
# Out:
# /kaggle/working/zip_folder.zip

# %%
# %cd /kaggle/working/

# %% [markdown]
# code feature map

# %%
results = model.predict(source='/kaggle/input/image-test/519_jpg.rf.ea92693e1eb62126f0c693684f29d292.jpg', visualize=True, save_crop=True, save=True, line_width=2, show_labels=False, save_txt=True)
# Out:
# Saving runs/detect/train2/519_jpg.rf.ea92693e1eb62126f0c693684f29d292/stage0_Conv_features.png... (32/80)
# Saving runs/detect/train2/519_jpg.rf.ea92693e1eb62126f0c693684f29d292/stage1_Conv_features.png... (32/160)
# Saving runs/detect/train2/519_jpg.rf.ea92693e1eb62126f0c693684f29d292/stage2_C2f_features.png... (32/160)
# Saving runs/detect/train2/519_jpg.rf.ea92693e1eb62126f0c693684f29d292/stage3_Conv_features.png... (32/320)
# Saving runs/detect/train2/519_jpg.rf.ea92693e1eb62126f0c693684f29d292/stage4_C2f_features.png... (32/320)
# Saving runs/detect/train2/519_jpg.rf.ea92693e1eb62126f0c693684f29d292/stage5_Conv_features.png... (32/640)
# Saving runs/detect/train2/519_jpg.rf.ea92693e1eb62126f0c693684f29d292/stage6_C2f_features.png... (32/640)
# Saving runs/detect/train2/519_jpg.rf.ea92693e1eb62126f0c693684f29d292/stage7_Conv_features.png... (32/640)
# Saving runs/detect/train2/519_jpg.rf.ea92693e1eb62126f0c693684f29d292/stage8_C2f_features.png... (32/640)
# ...

# %%
from IPython.display import FileLink

def download_file(file_path):
    return FileLink(file_path)

download_file('/kaggle/working/out-folder.zip')
# Out:
# /kaggle/working/out-folder.zip

# %%
from IPython.display import FileLink

#FileLink('/kaggle/working/open-4.zip')
#FileLink('/kaggle/working/open-4/runs.zip')
# !zip -r out-folder.zip runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/predict2/ (stored 0%)
#   adding: runs/detect/predict2/2606_jpg.rf.e29baa2d1a0dbe237e4277af0b820aed.jpg (deflated 26%)
#   adding: runs/detect/predict2/1341_jpg.rf.40500fd3035b3d909516e5e410840813.jpg (deflated 8%)
#   adding: runs/detect/predict2/2521_jpg.rf.fba628c770561b6292fcc7207802d760.jpg (deflated 14%)
#   adding: runs/detect/predict2/147_jpg.rf.ce6e189d16d828e175009f446294d3d2.jpg (deflated 8%)
#   adding: runs/detect/predict2/2952_jpg.rf.acdc65fd81413a5f80c0b00cfd24d7b3.jpg (deflated 18%)
#   adding: runs/detect/predict2/854_jpg.rf.a5ebe41a0fed328d39140dc93b165e7b.jpg (deflated 29%)
#   adding: runs/detect/predict2/624_jpg.rf.fc6811e1b467e98df820855fc1d6e637.jpg (deflated 19%)
#   adding: runs/detect/predict2/2637_jpg.rf.06283c98a640a68a16dba6e80f27ea60.jpg (deflated 9%)
#   adding: runs/detect/predict2/281_jpg.rf.cc7924877c7dead9b7e410f9f319a247.jpg (deflated 20%)
# ...
